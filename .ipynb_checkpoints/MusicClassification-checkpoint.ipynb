# %% [markdown]
# # Importing all required libraries
# I am using *librosa* to process the audio.  workflow:  stream audio files into notebook,  associate them with their respective labels,  generate features,  train binary classification model,  predict and evaluate!

# %%
import librosa as lr
from librosa import display
import numpy as np
import pandas as pd
import sklearn as sl
import matplotlib as plt
from sklearn.linear_model import LogisticRegression

# %%
X = []
y = []
sr = 0

for i in range(8):
    consonant = lr.load(('consonant' + str(i+1) + '.ogg'))
    dissonant = lr.load(('dissonant' + str(i+1) + '.ogg'))
    sr = consonant[1]
    X.append(consonant)
    X.append(dissonant)
    X[2*i] = list(X[2*i][0])
    X[2*i+1] = list(X[2*i+1][0])
    X[2*i].append(sum(lr.zero_crossings(np.asarray(X[2*i]), pad=False)))
    spectral_centroids = lr.feature.spectral_centroid(X[2*i][0:2035], sr=sr)[0]
    X[2*i+1].append(sum(lr.zero_crossings(np.asarray(X[2*i+1]), pad=False)))
    

#     X[2*i].append(int(lr.zero_crossings(X[2*i], pad=False)))
    y.append('consonant')
    y.append('dissonant')

X = np.asarray(X)
# X = np.delete(X, 1, axis=1) drops the row with sampling rate if needed
y = np.asarray(y, dtype=str)
y = y.reshape(16)
X = pd.DataFrame(X)
X.index.name = 'sound file'

# %% [markdown]
# # Making sure files imported successfully
#
# Here I use *librosa*'s display module to display a spectrogram of a wave

# %%
import IPython.display as ipd
lr.display.waveplot(X.to_numpy()[0], sr=44100)
X.shape()y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-901d961e73a5> in <module>
#       1 import IPython.display as ipd
#       2 lr.display.waveplot(X.to_numpy()[0], sr=44100)
# ----> 3 X.shape()
#
# TypeError: 'tuple' object is not callable

# %%
ipd.Audio(X.to_numpy()[4], rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
